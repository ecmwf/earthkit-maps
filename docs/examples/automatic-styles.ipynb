# %%
import yaml

import earthkit
from earthkit.maps.charts import styles

# %%
options = yaml.safe_load(
    """
    10m-wind-gust-6h:
      style:
        levels: [10, 15, 20, 25, 30, 35, 50]
        colors: ["sky", "greenish_blue", "avocado", "orange", "orangish_red", "violet"]
      metadata-match:
        - units: m s-1
        - short_name: 10fg6
          name: 10 metre wind gust in the last 6 hours
    """
)

# %%
data = earthkit.data.from_source("file", "/Users/mavj/Downloads/wgust_ens.grib")
data.ls()
# Out:
#     centre shortName typeOfLevel  level  dataDate  dataTime stepRange  \
# 0     ecmf     10fg6     surface      0  20140807         0     72-78
# 1     ecmf     10fg6     surface      0  20140807         0     72-78
# 2     ecmf     10fg6     surface      0  20140807         0     72-78
# 3     ecmf     10fg6     surface      0  20140807         0     72-78
# 4     ecmf     10fg6     surface      0  20140807         0     72-78
# ..     ...       ...         ...    ...       ...       ...       ...
# 148   ecmf     10fg6     surface      0  20140807         0     84-90
# 149   ecmf     10fg6     surface      0  20140807         0     84-90
# 150   ecmf     10fg6     surface      0  20140807         0     72-78
# 151   ecmf     10fg6     surface      0  20140807         0     78-84
# 152   ecmf     10fg6     surface      0  20140807         0     84-90
#
#     dataType  number    gridType
# 0         pf       1  regular_ll
# 1         pf       2  regular_ll
# ...

# %%
styles.guess(data, options)
# Out:
# {'levels': [10, 15, 20, 25, 30, 35, 50],
#  'colors': ['sky',
#   'greenish_blue',
#   'avocado',
#   'orange',
#   'orangish_red',
#   'violet']}
