# %%
import earthkit
from earthkit.maps import Chart

# %%
ens_data = earthkit.data.from_source("file", "/Users/mavj/Downloads/wgust_ens.grib")
data = ens_data.sel(stepRange="72-78")
data.ls()
# Out:
#    centre shortName typeOfLevel  level  dataDate  dataTime stepRange dataType  \
# 0    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 1    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 2    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 3    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 4    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 5    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 6    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 7    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 8    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 9    ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 10   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 11   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 12   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 13   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 14   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 15   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 16   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 17   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 18   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 19   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 20   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 21   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 22   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 23   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 24   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 25   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 26   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 27   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 28   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 29   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 30   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 31   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 32   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 33   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 34   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 35   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 36   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 37   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 38   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 39   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 40   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 41   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 42   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 43   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 44   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 45   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 46   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 47   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 48   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 49   ecmf     10fg6     surface      0  20140807         0     72-78       pf
# 50   ecmf     10fg6     surface      0  20140807         0     72-78       cf
#
#     number    gridType
# 0        1  regular_ll
# 1        2  regular_ll
# 2        3  regular_ll
# 3        4  regular_ll
# 4        5  regular_ll
# 5        6  regular_ll
# 6        7  regular_ll
# 7        8  regular_ll
# 8        9  regular_ll
# 9       10  regular_ll
# 10      11  regular_ll
# 11      12  regular_ll
# 12      13  regular_ll
# 13      14  regular_ll
# 14      15  regular_ll
# 15      16  regular_ll
# 16      17  regular_ll
# 17      18  regular_ll
# 18      19  regular_ll
# 19      20  regular_ll
# 20      21  regular_ll
# 21      22  regular_ll
# 22      23  regular_ll
# 23      24  regular_ll
# 24      25  regular_ll
# 25      26  regular_ll
# 26      27  regular_ll
# 27      28  regular_ll
# 28      29  regular_ll
# 29      30  regular_ll
# 30      31  regular_ll
# 31      32  regular_ll
# 32      33  regular_ll
# 33      34  regular_ll
# 34      35  regular_ll
# 35      36  regular_ll
# 36      37  regular_ll
# 37      38  regular_ll
# 38      39  regular_ll
# 39      40  regular_ll
# 40      41  regular_ll
# 41      42  regular_ll
# 42      43  regular_ll
# 43      44  regular_ll
# 44      45  regular_ll
# 45      46  regular_ll
# 46      47  regular_ll
# 47      48  regular_ll
# 48      49  regular_ll
# 49      50  regular_ll
# 50       0  regular_ll

# %%
chart = Chart()

colors = ["sky", "greenish_blue", "avocado", "orange", "orangish_red", "violet"]
levels = [10, 15, 20, 25, 30, 35, 50]

chart.shaded_contour(data, colors=colors, levels=levels)
chart.contour(data, colors="navy", levels=levels)

chart.land()
chart.coastlines()
chart.borders()
chart.gridlines(draw_labels=False)

chart.legend(location="bottom")

chart.subplot_titles("PF={number}")
chart.subplots[-1].title("CF")

chart.title()

chart.show()
