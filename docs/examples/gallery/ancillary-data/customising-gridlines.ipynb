# %% [markdown]
# ## Customising gridlines

# %%
import earthkit.maps

chart = earthkit.maps.Chart(crs="Robinson")

chart.land(color="darkslategrey")

chart.gridlines(xstep=10, ystep=10, ylim=80, linestyle="solid", draw_labels=False)

chart.show()
