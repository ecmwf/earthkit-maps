# %%
from earthkit.maps import Tile

# %%
tile = Tile([135, 157.5, -22.5, 0])
tile.shaded_contour("data/era5.nc")
chart.save("tile.png")
# Out:
# /Users/mavj/spice/magpye/earthkit/maps/inputs.py:154: UserWarning: No CF-compliant proj information detected in netCDF attributes; assuming +proj=eqc +ellps=WGS84 +a=6378137.0 +lon_0=0.0 +to_meter=111319.4907932736 +vto_meter=1 +no_defs +type=crs CRS
#   warnings.warn(f"{err}; assuming {schema.reference_crs} CRS")
